# %%
# %run train_umbrella_logistic_demo.py
# Out:
# Coeficientes aprendidos:
#          feature  coefficient
# rain_probability     1.144869
#  is_rainy_season     0.278674
#       wind_speed     0.106277
#       cloudiness     0.090901
#         humidity    -0.088214
#
# Mismo dia, solo cambia rain_probability:
# rain_probability = 0.15 -> 0.3934
# rain_probability = 0.85 -> 0.9602

# %%
# %run generate_synthetic_mortgage_dataset.py --rows 2000 --output synthetic_mortgage_dataset.csv
# Out:
# Wrote 2000 rows to synthetic_mortgage_dataset.csv

# %%
import pandas as pd

df = pd.read_csv("synthetic_mortgage_dataset.csv")
df.head()
# Out:
#   application_id  net_monthly_income  monthly_debt_payment  monthly_expenses  \
# 0     APP-000000             9475.09               4265.36           5560.73
# 1     APP-000001             5172.05               1121.72           2830.55
# 2     APP-000002            10901.44               2882.91           6360.78
# 3     APP-000003            11509.81               1895.59           1381.18
# 4     APP-000004             2500.00                  0.00           1743.41
#
#    property_value  requested_amount  requested_term_months  active_loan_count  \
# 0       586175.62         441341.34                    240                  3
# 1       300052.40         250957.34                    240                  3
# 2       848265.07         640891.21                    180                  3
# 3       857864.82         840707.52                    300                  2
# 4       120000.00         108704.68                    240                  1
#
#    has_late_payments  employment_tenure_months  ...  debt_to_income_ratio  \
# 0                  0                        35  ...                0.4502
# 1                  0                        48  ...                0.2169
# 2                  0                        26  ...                0.2645
# 3                  0                        56  ...                0.1647
# 4                  0                        39  ...                0.0000
#
#    loan_to_value_ratio  payment_to_income_ratio  expense_to_income_ratio  \
# 0               0.7529                   0.1941                   0.5869
# 1               0.8364                   0.2022                   0.5473
# 2               0.7555                   0.3266                   0.5835
# 3               0.9800                   0.2435                   0.1200
# 4               0.9059                   0.1812                   0.6974
#
#    total_obligations_to_income_ratio  employment_stability_score  \
# 0                             1.2311                          80
# 1                             0.9663                          80
# 2                             1.1745                          80
# 3                             0.5282                          80
# 4                             0.8785                          80
#
#    banking_capacity_score  credit_history_score  default_flag  \
# 0                      75                    76             1
# 1                      55                    76             1
# 2                      75                    76             1
# 3                      55                    84             0
# 4                      75                    92             1
#
#    recommended_amount
# 0                 0.0
# 1            126000.0
# 2            128000.0
# 3            537000.0
# 4             88000.0
#
# [5 rows x 22 columns]

# %%
df["default_flag"].value_counts(normalize=True)
# Out:
# default_flag
# 1    0.5465
# 0    0.4535
# Name: proportion, dtype: float64

# %%
df[[
    "debt_to_income_ratio",
    "loan_to_value_ratio",
    "payment_to_income_ratio",
    "expense_to_income_ratio",
    "total_obligations_to_income_ratio",
    "employment_stability_score",
    "banking_capacity_score",
    "credit_history_score",
    "default_flag",
]].describe()
# Out:
#        debt_to_income_ratio  loan_to_value_ratio  payment_to_income_ratio  \
# count           2000.000000          2000.000000              2000.000000
# mean               0.221842             0.720737                 0.253378
# std                0.135570             0.127477                 0.115302
# min                0.000000             0.350000                 0.037700
# 25%                0.124500             0.633100                 0.176075
# 50%                0.217600             0.723250                 0.228500
# 75%                0.310750             0.805175                 0.305850
# max                0.750000             0.980000                 0.902800
#
#        expense_to_income_ratio  total_obligations_to_income_ratio  \
# count              2000.000000                        2000.000000
# mean                  0.419253                           0.894470
# std                   0.155747                           0.238819
# min                   0.120000                           0.239000
# 25%                   0.310275                           0.729900
# 50%                   0.414750                           0.882750
# 75%                   0.527050                           1.047825
# max                   0.850000                           2.044800
#
#        employment_stability_score  banking_capacity_score  \
# count                  2000.00000             2000.000000
# mean                     83.74750               63.290000
# std                      15.83964               17.409838
# min                      35.00000               30.000000
# 25%                      80.00000               55.000000
# 50%                      80.00000               75.000000
# 75%                     100.00000               75.000000
# max                     100.00000              100.000000
#
#        credit_history_score  default_flag
# count            2000.00000   2000.000000
# mean               85.59400      0.546500
# std                15.41947      0.497958
# min                25.00000      0.000000
# 25%                84.00000      0.000000
# 50%                92.00000      1.000000
# 75%               100.00000      1.000000
# max               100.00000      1.000000
